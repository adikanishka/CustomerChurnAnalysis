# %% [markdown]
# <a href="https://colab.research.google.com/github/adikanishka/CustomerChurnAnalysis/blob/main/LSTM_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at rakesh@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'a': 5,
#  'of': 6,
#  'is': 7,
#  'have': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'course': 12,
#  'program': 13,
#  'for': 14,
#  'all': 15,
#  'sessions': 16,
#  'in': 17,
#  'on': 18,
#  'be': 19,
#  'and': 20,
#  'this': 21,
#  'if': 22,
#  'am': 23,
#  'pay': 24,
#  'payment': 25,
#  'make': 26,
#  'we': 27,
#  'do': 28,
#  'subscription': 29,
#  'where': 30,
#  'rs': 31,
#  'so': 32,
#  'session': 33,
#  'our': 34,
#  'paid': 35,
#  'join': 36,
#  'able': 37,
#  'your': 38,
#  'website': 39,
#  'placement': 40,
#  'fee': 41,
#  'monthly': 42,
#  'month': 43,
#  'not': 44,
#  'get': 45,
#  'yes': 46,
#  'once': 47,
#  'past': 48,
#  'feb': 49,
#  'assistance': 50,
#  'data': 51,
#  '7': 52,
#  '5600': 53,
#  'are': 54,
#  'watch': 55,
#  'by': 56,
#  'mail': 57,
#  'from': 58,
#  'contact': 59,
#  'us': 60,
#  'at': 61,
#  'or': 62,
#  'doubt': 63,
#  'science': 64,
#  'payments': 65,
#  '799': 66,
#  'total': 67,
#  'duration': 68,
#  'months': 69,
#  'learning': 70,
#  'case': 71,
#  'here': 72,
#  'part': 73,
#  'google': 74,
#  'see': 75,
#  'late': 76,
#  'dashboard': 77,
#  'task': 78,
#  'don’t': 79,
#  'com': 80,
#  'validity': 81,
#  '15th': 82,
#  'jan': 83,
#  'period': 84,
#  'after': 85,
#  'till': 86,
#  '21st': 87,
#  'that': 88,
#  'about': 89,
#  'mentorship': 90,
#  'follows': 91,
#  'model': 92,
#  'syllabus': 93,
#  'python': 94,
#  'ml': 95,
#  'studies': 96,
#  'deep': 97,
#  'nlp': 98,
#  'no': 99,
#  'miss': 100,
#  'live': 101,
#  'recording': 102,
#  'even': 103,
#  'class': 104,
#  'time': 105,
#  '2': 106,
#  'how': 107,
#  'absolutely': 108,
#  'middle': 109,
#  'anytime': 110,
#  'submit': 111,
#  'with': 112,
#  'gmail': 113,
#  'registration': 114,
#  'related': 115,
#  'link': 116,
#  'entire': 117,
#  'suppose': 118,
#  'again': 119,
#  'days': 120,
#  'day': 121,
#  'refund': 122,
#  'living': 123,
#  'outside': 124,
#  'india': 125,
#  'should': 126,
#  'sending': 127,
#  'nitish': 128,
#  'campusx': 129,
#  'queries': 130,
#  'videos': 131,
#  'read': 132,
#  'but': 133,
#  'provided': 134,
#  'form': 135,
#  '1': 136,
#  'clearance': 137,
#  'week': 138,
#  'just': 139,
#  'certificate': 140,
#  'earlier': 141,
#  'comes': 142,
#  'under': 143,
#  'guarantee': 144,
#  'dsmp': 145,
#  '2023': 146,
#  'becomes': 147,
#  'approx': 148,
#  'covering': 149,
#  'following': 150,
#  'modules': 151,
#  'fundamentals': 152,
#  'libraries': 153,
#  'analysis': 154,
#  'sql': 155,
#  'maths': 156,
#  'machine': 157,
#  'algorithms': 158,
#  'practical': 159,
#  'mlops': 160,
#  'check': 161,
#  'detailed': 162,
#  'both': 163,
#  'program’s': 164,
#  'curriculum': 165,
#  'recorded': 166,
#  'go': 167,
#  'back': 168,
#  'find': 169,
#  'schedule': 170,
#  'checkout': 171,
#  'sheet': 172,
#  'table': 173,
#  'roughly': 174,
#  'last': 175,
#  'hours': 176,
#  'language': 177,
#  'spoken': 178,
#  'instructor': 179,
#  'during': 180,
#  'hinglish': 181,
#  'informed': 182,
#  'upcoming': 183,
#  'side': 184,
#  'before': 185,
#  'every': 186,
#  'become': 187,
#  'user': 188,
#  'non': 189,
#  'tech': 190,
#  'background': 191,
#  'lectures': 192,
#  'content': 193,
#  'provide': 194,
#  'solutions': 195,
#  'self': 196,
#  'evaluate': 197,
#  'yourself': 198,
#  'rakesh': 199,
#  'questions': 200,
#  'youtube': 201,
#  'channel': 202,
#  'amount': 203,
#  'unfortunately': 204,
#  'then': 205,
#  '1st': 206,
#  '30': 207,
#  'essentially': 208,
#  'wait': 209,
#  'end': 210,
#  'like': 211,
#  'making': 212,
#  'policy': 213,
#  'made': 214,
#  'post': 215,
#  'when': 216,
#  'view': 217,
#  'one': 218,
#  'tricky': 219,
#  'carefully': 220,
#  'valid': 221,
#  'purchased': 222,
#  '20th': 223,
#  'purchase': 224,
#  'over': 225,
#  'installments': 226,
#  'aug': 227,
#  '2024': 228,
#  'why': 229,
#  'lifetime': 230,
#  'because': 231,
#  'low': 232,
#  'reach': 233,
#  'out': 234,
#  'fill': 235,
#  'team': 236,
#  'still': 237,
#  'ask': 238,
#  'doubts': 239,
#  'select': 240,
#  'gmai': 241,
#  'criteria': 242,
#  'there': 243,
#  'criterias': 244,
#  'attempt': 245,
#  'assessments': 246,
#  'joining': 247,
#  'current': 248,
#  'clarify': 249,
#  'does': 250,
#  'mean': 251,
#  'dont': 252,
#  'any': 253,
#  'jobs': 254,
#  'matter': 255,
#  'interview': 256,
#  'calls': 257,
#  'planning': 258,
#  'placements': 259,
#  'afraid': 260,
#  'disappointed': 261,
#  'portfolio': 262,
#  'building': 263,
#  'soft': 264,
#  'skill': 265,
#  'industry': 266,
#  'mentors': 267,
#  'discussion': 268,
#  'job': 269,
#  'hunting': 270,
#  'strategies': 271}

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]


  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])
print(input_sequences)
# Out:
# [[89, 1], [89, 1, 13], [11, 7], [11, 7, 1], [11, 7, 1, 12], [11, 7, 1, 12, 41], [11, 7, 1, 12, 41, 14], [11, 7, 1, 12, 41, 14, 51], [11, 7, 1, 12, 41, 14, 51, 64], [11, 7, 1, 12, 41, 14, 51, 64, 90], [11, 7, 1, 12, 41, 14, 51, 64, 90, 13], [11, 7, 1, 12, 41, 14, 51, 64, 90, 13, 145], [11, 7, 1, 12, 41, 14, 51, 64, 90, 13, 145, 146], [1, 12], [1, 12, 91], [1, 12, 91, 5], [1, 12, 91, 5, 42], [1, 12, 91, 5, 42, 29], [1, 12, 91, 5, 42, 29, 92], [1, 12, 91, 5, 42, 29, 92, 30], [1, 12, 91, 5, 42, 29, 92, 30, 2], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31, 66], [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31, 66, 43], [11, 7], [11, 7, 1], [11, 7, 1, 67], [11, 7, 1, 67, 68], [11, 7, 1, 67, 68, 6], [11, 7, 1, 67, 68, 6, 1], [11, 7, 1, 67, 68, 6, 1, 12], [1, 67], [1, 67, 68], [1, 67, 68, 6], [1, 67, 68, 6, 1], [1, 67, 68, 6, 1, 12], [1, 67, 68, 6, 1, 12, 7], [1, 67, 68, 6, 1, 12, 7, 52], [1, 67, 68, 6, 1, 12, 7, 52, 69], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31, 53], [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31, 53, 148], [11, 7], [11, 7, 1], [11, 7, 1, 93], [11, 7, 1, 93, 6], [11, 7, 1, 93, 6, 1], [11, 7, 1, 93, 6, 1, 90], [11, 7, 1, 93, 6, 1, 90, 13], [27, 9], [27, 9, 19], [27, 9, 19, 149], [27, 9, 19, 149, 1], [27, 9, 19, 149, 1, 150], [27, 9, 19, 149, 1, 150, 151], [94, 152], [94, 153], [94, 153, 14], [94, 153, 14, 51], [94, 153, 14, 51, 64], [51, 154], [155, 14], [155, 14, 51], [155, 14, 51, 64], [156, 14], [156, 14, 157], [156, 14, 157, 70], [95, 158], [159, 95], [71, 96], [2, 10], [2, 10, 161], [2, 10, 161, 1], [2, 10, 161, 1, 162], [2, 10, 161, 1, 162, 93], [2, 10, 161, 1, 162, 93, 72], [9, 97], [9, 97, 70], [9, 97, 70, 20], [9, 97, 70, 20, 98], [9, 97, 70, 20, 98, 19], [9, 97, 70, 20, 98, 19, 5], [9, 97, 70, 20, 98, 19, 5, 73], [9, 97, 70, 20, 98, 19, 5, 73, 6], [9, 97, 70, 20, 98, 19, 5, 73, 6, 21], [9, 97, 70, 20, 98, 19, 5, 73, 6, 21, 13], [99, 98], [99, 98, 20], [99, 98, 20, 97], [99, 98, 20, 97, 70], [99, 98, 20, 97, 70, 163], [99, 98, 20, 97, 70, 163, 54], [99, 98, 20, 97, 70, 163, 54, 44], [99, 98, 20, 97, 70, 163, 54, 44, 5], [99, 98, 20, 97, 70, 163, 54, 44, 5, 73], [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6], [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21], [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21, 164], [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21, 164, 165], [11, 22], [11, 22, 3], [11, 22, 3, 100], [11, 22, 3, 100, 5], [11, 22, 3, 100, 5, 101], [11, 22, 3, 100, 5, 101, 33], [11, 22, 3, 100, 5, 101, 33, 9], [11, 22, 3, 100, 5, 101, 33, 9, 3], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6, 1], [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6, 1, 33], [46, 15], [46, 15, 34], [46, 15, 34, 16], [46, 15, 34, 16, 54], [46, 15, 34, 16, 54, 166], [46, 15, 34, 16, 54, 166, 32], [46, 15, 34, 16, 54, 166, 32, 103], [46, 15, 34, 16, 54, 166, 32, 103, 22], [46, 15, 34, 16, 54, 166, 32, 103, 22, 2], [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100], [46, 15, 34,  ...

# %%
print(tokenized_sentence)
# Out:
# []

# %%
input_sequences
# Out:
# [[89, 1],
#  [89, 1, 13],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 12],
#  [11, 7, 1, 12, 41],
#  [11, 7, 1, 12, 41, 14],
#  [11, 7, 1, 12, 41, 14, 51],
#  [11, 7, 1, 12, 41, 14, 51, 64],
#  [11, 7, 1, 12, 41, 14, 51, 64, 90],
#  [11, 7, 1, 12, 41, 14, 51, 64, 90, 13],
#  [11, 7, 1, 12, 41, 14, 51, 64, 90, 13, 145],
#  [11, 7, 1, 12, 41, 14, 51, 64, 90, 13, 145, 146],
#  [1, 12],
#  [1, 12, 91],
#  [1, 12, 91, 5],
#  [1, 12, 91, 5, 42],
#  [1, 12, 91, 5, 42, 29],
#  [1, 12, 91, 5, 42, 29, 92],
#  [1, 12, 91, 5, 42, 29, 92, 30],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31, 66],
#  [1, 12, 91, 5, 42, 29, 92, 30, 2, 8, 4, 26, 42, 65, 6, 31, 66, 43],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 67],
#  [11, 7, 1, 67, 68],
#  [11, 7, 1, 67, 68, 6],
#  [11, 7, 1, 67, 68, 6, 1],
#  [11, 7, 1, 67, 68, 6, 1, 12],
#  [1, 67],
#  [1, 67, 68],
#  [1, 67, 68, 6],
#  [1, 67, 68, 6, 1],
#  [1, 67, 68, 6, 1, 12],
#  [1, 67, 68, 6, 1, 12, 7],
#  [1, 67, 68, 6, 1, 12, 7, 52],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31, 53],
#  [1, 67, 68, 6, 1, 12, 7, 52, 69, 32, 1, 67, 12, 41, 147, 66, 52, 31, 53, 148],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 93],
#  [11, 7, 1, 93, 6],
#  [11, 7, 1, 93, 6, 1],
#  [11, 7, 1, 93, 6, 1, 90],
#  [11, 7, 1, 93, 6, 1, 90, 13],
#  [27, 9],
#  [27, 9, 19],
#  [27, 9, 19, 149],
#  [27, 9, 19, 149, 1],
#  [27, 9, 19, 149, 1, 150],
#  [27, 9, 19, 149, 1, 150, 151],
#  [94, 152],
#  [94, 153],
#  [94, 153, 14],
#  [94, 153, 14, 51],
#  [94, 153, 14, 51, 64],
#  [51, 154],
#  [155, 14],
#  [155, 14, 51],
#  [155, 14, 51, 64],
#  [156, 14],
#  [156, 14, 157],
#  [156, 14, 157, 70],
#  [95, 158],
#  [159, 95],
#  [71, 96],
#  [2, 10],
#  [2, 10, 161],
#  [2, 10, 161, 1],
#  [2, 10, 161, 1, 162],
#  [2, 10, 161, 1, 162, 93],
#  [2, 10, 161, 1, 162, 93, 72],
#  [9, 97],
#  [9, 97, 70],
#  [9, 97, 70, 20],
#  [9, 97, 70, 20, 98],
#  [9, 97, 70, 20, 98, 19],
#  [9, 97, 70, 20, 98, 19, 5],
#  [9, 97, 70, 20, 98, 19, 5, 73],
#  [9, 97, 70, 20, 98, 19, 5, 73, 6],
#  [9, 97, 70, 20, 98, 19, 5, 73, 6, 21],
#  [9, 97, 70, 20, 98, 19, 5, 73, 6, 21, 13],
#  [99, 98],
#  [99, 98, 20],
#  [99, 98, 20, 97],
#  [99, 98, 20, 97, 70],
#  [99, 98, 20, 97, 70, 163],
#  [99, 98, 20, 97, 70, 163, 54],
#  [99, 98, 20, 97, 70, 163, 54, 44],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5, 73],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21, 164],
#  [99, 98, 20, 97, 70, 163, 54, 44, 5, 73, 6, 21, 164, 165],
#  [11, 22],
#  [11, 22, 3],
#  [11, 22, 3, 100],
#  [11, 22, 3, 100, 5],
#  [11, 22, 3, 100, 5, 101],
#  [11, 22, 3, 100, 5, 101, 33],
#  [11, 22, 3, 100, 5, 101, 33, 9],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6, 1],
#  [11, 22, 3, 100, 5, 101, 33, 9, 3, 45, 5, 102, 6, 1, 33],
#  [46, 15],
#  [46, 15, 34],
#  [46, 15, 34, 16],
#  [46, 15, 34, 16, 54],
#  [46, 15, 34, 16, 54, 166],
#  [46, 15, 34, 16, 54, 166, 32],
#  [46, 15, 34, 16, 54, 166, 32, 103],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33, 2],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33, 2, 10],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33, 2, 10, 167],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33, 2, 10, 167, 168],
#  [46, 15, 34, 16, 54, 166, 32, 103, 22, 2, 100, 5, 33, 2, 10, 167, 168, 20],
#  [46,
#   15,
#   34,
#   16,
#   54,
#   166,
#   32,
#   103,
#   22,
#   2,
#   100,
#   5,
#   33,
#   2,
#   10,
#   167,
#   168,
#   20,
#   55],
#  [46,
#   15,
#   34,
#   16,
#   54,
#   166,
#   32,
#   103,
#   22,
#   2,
#   100,
#   5,
#   33,
#   2,
#   10,
#   167,
#   168,
#   20,
#   55,
#   1],
#  [46,
#   15,
#   34,
#   16,
#   54,
#   166,
#   32,
#   103,
#   22,
#   2,
#   100,
#   5,
#   33,
#   2,
#   10,
#   167,
#   168,
#   20,
#   55,
#   1,
#   102],
#  [30, 10],
#  [30, 10, 3],
#  [30, 10, 3, 169],
#  [30, 10, 3, 169, 1],
#  [30, 10, 3, 169, 1, 104],
#  [30, 10, 3, 169, 1, 104, 170],
#  [171, 21],
#  [171, 21, 74],
#  [171, 21, 74, 172],
#  [171, 21, 74, 172, 4],
#  [171, 21, 74, 172, 4, 75],
#  [171, 21, 74, 172, 4, 75, 43],
#  [171, 21, 74, 172, 4, 75, 43, 56],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43, 105],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43, 105, 173],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43, 105, 173, 6],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43, 105, 173, 6, 1],
#  [171, 21, 74, 172, 4, 75, 43, 56, 43, 105, 173, 6, 1, 12],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 105],
#  [11, 7, 1, 105, 68],
#  [11, 7, 1, 105, 68, 6],
#  [11, 7, 1, 105, 68, 6, 15],
#  [11, 7, 1, 105, 68, 6, 15, 1],
#  [11, 7, 1, 105, 68, 6, 15, 1, 101],
#  [11, 7, 1, 105, 68, 6, 15, 1, 101, 16],
#  [174, 15],
#  [174, 15, 1],
#  [174, 15, 1, 16],
#  [174, 15, 1, 16, 175],
#  [174, 15, 1, 16, 175, 106],
#  [174, 15, 1, 16, 175, 106, 176],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 177],
#  [11, 7, 1, 177, 178],
#  [11, 7, 1, 177, 178, 56],
#  [11, 7, 1, 177, 178, 56, 1],
#  [11, 7, 1, 177, 178, 56, 1, 179],
#  [11, 7, 1, 177, 178, 56, 1, 179, 180],
#  [11, 7, 1, 177, 178, 56, 1, 179, 180, 1],
#  [11, 7, 1, 177, 178, 56, 1, 179, 180, 1, 16],
#  [107, 9],
#  [107, 9, 3],
#  [107, 9, 3, 19],
#  [107, 9, 3, 19, 182],
#  [107, 9, 3, 19, 182, 89],
#  [107, 9, 3, 19, 182, 89, 1],
#  [107, 9, 3, 19, 182, 89, 1, 183],
#  [107, 9, 3, 19, 182, 89, 1, 183, 104],
#  [2, 9],
#  [2, 9, 45],
#  [2, 9, 45, 5],
#  [2, 9, 45, 5, 57],
#  [2, 9, 45, 5, 57, 58],
#  [2, 9, 45, 5, 57, 58, 34],
#  [2, 9, 45, 5, 57, 58, 34, 184],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47, 2],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47, 2, 187],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47, 2, 187, 5],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47, 2, 187, 5, 35],
#  [2, 9, 45, 5, 57, 58, 34, 184, 185, 186, 35, 33, 47, 2, 187, 5, 35, 188],
#  [10, 3],
#  [10, 3, 28],
#  [10, 3, 28, 21],
#  [10, 3, 28, 21, 12],
#  [10, 3, 28, 21, 12, 22],
#  [10, 3, 28, 21, 12, 22, 3],
#  [10, 3, 28, 21, 12, 22, 3, 23],
#  [10, 3, 28, 21, 12, 22, 3, 23, 58],
#  [10, 3, 28, 21, 12, 22, 3, 23, 58, 5],
#  [10, 3, 28, 21, 12, 22, 3, 23, 58, 5, 189],
#  [10, 3, 28, 21, 12, 22, 3, 23, 58, 5, 189, 190],
#  [10, 3, 28, 21, 12, 22, 3, 23, 58, 5, 189, 190, 191],
#  [46, 108],
#  [3, 23],
#  [3, 23, 76],
#  [3, 23, 76, 10],
#  [3, 23, 76, 10, 3],
#  [3, 23, 76, 10, 3, 36],
#  [3, 23, 76, 10, 3, 36, 1],
#  [3, 23, 76, 10, 3, 36, 1, 13],
#  [3, 23, 76, 10, 3, 36, 1, 13, 17],
#  [3, 23, 76, 10, 3, 36, 1, 13, 17, 1],
#  [3, 23, 76, 10, 3, 36, 1, 13, 17, 1, 109],
#  [108, 2],
#  [108, 2, 10],
#  [108, 2, 10, 36],
#  [108, 2, 10, 36, 1],
#  [108, 2, 10, 36, 1, 13],
#  [108, 2, 10, 36, 1, 13, 110],
#  [22, 3],
#  [22, 3, 36],
#  [22, 3, 36, 24],
#  [22, 3, 36, 24, 17],
#  [22, 3, 36, 24, 17, 1],
#  [22, 3, 36, 24, 17, 1, 109],
#  [22, 3, 36, 24, 17, 1, 109, 9],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4, 75],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4, 75, 15],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4, 75, 15, 1],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4, 75, 15, 1, 48],
#  [22, 3, 36, 24, 17, 1, 109, 9, 3, 19, 37, 4, 75, 15, 1, 48, 192],
#  [46, 47],
#  [46, 47, 2],
#  [46, 47, 2, 26],
#  [46, 47, 2, 26, 1],
#  [46, 47, 2, 26, 1, 25],
#  [46, 47, 2, 26, 1, 25, 2],
#  [46, 47, 2, 26, 1, 25, 2, 9],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1, 48],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1, 48, 193],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1, 48, 193, 17],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1, 48, 193, 17, 38],
#  [46, 47, 2, 26, 1, 25, 2, 9, 19, 37, 4, 75, 15, 1, 48, 193, 17, 38, 77],
#  [30, 28],
#  [30, 28, 3],
#  [30, 28, 3, 8],
#  [30, 28, 3, 8, 4],
#  [30, 28, 3, 8, 4, 111],
#  [30, 28, 3, 8, 4, 111, 1],
#  [30, 28, 3, 8, 4, 111, 1, 78],
#  [2, 79],
#  [2, 79, 8],
#  [2, 79, 8, 4],
#  [2, 79, 8, 4, 111],
#  [2, 79, 8, 4, 111, 1],
#  [2, 79, 8, 4, 111, 1, 78],
#  [2, 79, 8, 4, 111, 1, 78, 27],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2, 8],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2, 8, 4],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2, 8, 4, 196],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2, 8, 4, 196, 197],
#  [2, 79, 8, 4, 111, 1, 78, 27, 9, 194, 2, 112, 1, 195, 2, 8, 4, 196, 197, 1],
#  [2,
#   79,
#   8,
#   4,
#   111,
#   1,
#   78,
#   27,
#   9,
#   194,
#   2,
#   112,
#   1,
#   195,
#   2,
#   8,
#   4,
#   196,
#   197,
#   1,
#   78],
#  [2,
#   79,
#   8,
#   4,
#   111,
#   1,
#   78,
#   27,
#   9,
#   194,
#   2,
#   112,
#   1,
#   195,
#   2,
#   8,
#   4,
#   196,
#   197,
#   1,
#   78,
#   198],
#  [9, 27],
#  [9, 27, 28],
#  [9, 27, 28, 71],
#  [9, 27, 28, 71, 96],
#  [9, 27, 28, 71, 96, 17],
#  [9, 27, 28, 71, 96, 17, 1],
#  [9, 27, 28, 71, 96, 17, 1, 13],
#  [30, 10],
#  [30, 10, 27],
#  [30, 10, 27, 59],
#  [30, 10, 27, 59, 2],
#  [2, 10],
#  [2, 10, 57],
#  [2, 10, 57, 60],
#  [2, 10, 57, 60, 61],
#  [2, 10, 57, 60, 61, 199],
#  [2, 10, 57, 60, 61, 199, 113],
#  [2, 10, 57, 60, 61, 199, 113, 80],
#  [25, 114],
#  [25, 114, 115],
#  [25, 114, 115, 200],
#  [30, 28],
#  [30, 28, 27],
#  [30, 28, 27, 8],
#  [30, 28, 27, 8, 4],
#  [30, 28, 27, 8, 4, 26],
#  [30, 28, 27, 8, 4, 26, 34],
#  [30, 28, 27, 8, 4, 26, 34, 65],
#  [30, 28, 27, 8, 4, 26, 34, 65, 38],
#  [30, 28, 27, 8, 4, 26, 34, 65, 38, 201],
#  [30, 28, 27, 8, 4, 26, 34, 65, 38, 201, 202],
#  [30, 28, 27, 8, 4, 26, 34, 65, 38, 201, 202, 62],
#  [30, 28, 27, 8, 4, 26, 34, 65, 38, 201, 202, 62, 39],
#  [2, 8],
#  [2, 8, 4],
#  [2, 8, 4, 26],
#  [2, 8, 4, 26, 15],
#  [2, 8, 4, 26, 15, 38],
#  [2, 8, 4, 26, 15, 38, 42],
#  [2, 8, 4, 26, 15, 38, 42, 65],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7, 1],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7, 1, 116],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7, 1, 116, 14],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7, 1, 116, 14, 34],
#  [2, 8, 4, 26, 15, 38, 42, 65, 18, 34, 39, 72, 7, 1, 116, 14, 34, 39],
#  [10, 27],
#  [10, 27, 24],
#  [10, 27, 24, 1],
#  [10, 27, 24, 1, 117],
#  [10, 27, 24, 1, 117, 203],
#  [10, 27, 24, 1, 117, 203, 6],
#  [10, 27, 24, 1, 117, 203, 6, 31],
#  [10, 27, 24, 1, 117, 203, 6, 31, 53],
#  [10, 27, 24, 1, 117, 203, 6, 31, 53, 15],
#  [10, 27, 24, 1, 117, 203, 6, 31, 53, 15, 61],
#  [10, 27, 24, 1, 117, 203, 6, 31, 53, 15, 61, 47],
#  [204, 99],
#  [204, 99, 1],
#  [204, 99, 1, 13],
#  [204, 99, 1, 13, 91],
#  [204, 99, 1, 13, 91, 5],
#  [204, 99, 1, 13, 91, 5, 42],
#  [204, 99, 1, 13, 91, 5, 42, 29],
#  [204, 99, 1, 13, 91, 5, 42, 29, 92],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 81],
#  [11, 7, 1, 81, 6],
#  [11, 7, 1, 81, 6, 42],
#  [11, 7, 1, 81, 6, 42, 29],
#  [11, 7, 1, 81, 6, 42, 29, 118],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205, 28],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205, 28, 3],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205, 28, 3, 8],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205, 28, 3, 8, 4],
#  [11, 7, 1, 81, 6, 42, 29, 118, 22, 3, 24, 18, 82, 83, 205, 28, 3, 8, 4, 24],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18,
#   206],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18,
#   206,
#   49],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18,
#   206,
#   49,
#   62],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18,
#   206,
#   49,
#   62,
#   82],
#  [11,
#   7,
#   1,
#   81,
#   6,
#   42,
#   29,
#   118,
#   22,
#   3,
#   24,
#   18,
#   82,
#   83,
#   205,
#   28,
#   3,
#   8,
#   4,
#   24,
#   119,
#   18,
#   206,
#   49,
#   62,
#   82,
#   49],
#  [82, 49],
#  [82, 49, 1],
#  [82, 49, 1, 81],
#  [82, 49, 1, 81, 84],
#  [82, 49, 1, 81, 84, 7],
#  [82, 49, 1, 81, 84, 7, 207],
#  [82, 49, 1, 81, 84, 7, 207, 120],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1, 25],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1, 25, 32],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1, 25, 32, 208],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1, 25, 32, 208, 2],
#  [82, 49, 1, 81, 84, 7, 207, 120, 58, 1, 121, 2, 26, 1, 25, 32, 208, 2, 10],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209,
#   14],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209,
#   14,
#   5],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209,
#   14,
#   5,
#   43],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209,
#   14,
#   5,
#   43,
#   4],
#  [82,
#   49,
#   1,
#   81,
#   84,
#   7,
#   207,
#   120,
#   58,
#   1,
#   121,
#   2,
#   26,
#   1,
#   25,
#   32,
#   208,
#   2,
#   10,
#   36,
#   110,
#   2,
#   79,
#   8,
#   4,
#   209,
#   14,
#   5,
#   43,
#   4,
#   210],
#  [11, 22],
#  [11, 22, 3],
#  [11, 22, 3, 79],
#  [11, 22, 3, 79, 211],
#  [11, 22, 3, 79, 211, 1],
#  [11, 22, 3, 79, 211, 1, 12],
#  [11, 22, 3, 79, 211, 1, 12, 85],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25, 11],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25, 11, 7],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25, 11, 7, 1],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25, 11, 7, 1, 122],
#  [11, 22, 3, 79, 211, 1, 12, 85, 212, 1, 25, 11, 7, 1, 122, 213],
#  [2, 45],
#  [2, 45, 5],
#  [2, 45, 5, 52],
#  [2, 45, 5, 52, 120],
#  [2, 45, 5, 52, 120, 122],
#  [2, 45, 5, 52, 120, 122, 84],
#  [2, 45, 5, 52, 120, 122, 84, 58],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121, 2],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121, 2, 8],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121, 2, 8, 214],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121, 2, 8, 214, 1],
#  [2, 45, 5, 52, 120, 122, 84, 58, 1, 121, 2, 8, 214, 1, 25],
#  [3, 23],
#  [3, 23, 123],
#  [3, 23, 123, 124],
#  [3, 23, 123, 124, 125],
#  [3, 23, 123, 124, 125, 20],
#  [3, 23, 123, 124, 125, 20, 3],
#  [3, 23, 123, 124, 125, 20, 3, 23],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39, 11],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39, 11, 126],
#  [3,
#   23,
#   123,
#   124,
#   125,
#   20,
#   3,
#   23,
#   44,
#   37,
#   4,
#   26,
#   1,
#   25,
#   18,
#   1,
#   39,
#   11,
#   126,
#   3],
#  [3,
#   23,
#   123,
#   124,
#   125,
#   20,
#   3,
#   23,
#   44,
#   37,
#   4,
#   26,
#   1,
#   25,
#   18,
#   1,
#   39,
#   11,
#   126,
#   3,
#   28],
#  [2, 8],
#  [2, 8, 4],
#  [2, 8, 4, 59],
#  [2, 8, 4, 59, 60],
#  [2, 8, 4, 59, 60, 56],
#  [2, 8, 4, 59, 60, 56, 127],
#  [2, 8, 4, 59, 60, 56, 127, 5],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129, 113],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129, 113, 80],
#  [215, 114],
#  [215, 114, 130],
#  [86, 216],
#  [86, 216, 10],
#  [86, 216, 10, 3],
#  [86, 216, 10, 3, 217],
#  [86, 216, 10, 3, 217, 1],
#  [86, 216, 10, 3, 217, 1, 35],
#  [86, 216, 10, 3, 217, 1, 35, 131],
#  [86, 216, 10, 3, 217, 1, 35, 131, 18],
#  [86, 216, 10, 3, 217, 1, 35, 131, 18, 1],
#  [86, 216, 10, 3, 217, 1, 35, 131, 18, 1, 39],
#  [21, 218],
#  [21, 218, 7],
#  [21, 218, 7, 219],
#  [21, 218, 7, 219, 32],
#  [21, 218, 7, 219, 32, 132],
#  [21, 218, 7, 219, 32, 132, 220],
#  [21, 218, 7, 219, 32, 132, 220, 2],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86, 38],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86, 38, 29],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86, 38, 29, 7],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86, 38, 29, 7, 221],
#  [21, 218, 7, 219, 32, 132, 220, 2, 10, 55, 1, 131, 86, 38, 29, 7, 221, 118],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8,
#   4],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8,
#   4,
#   224],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8,
#   4,
#   224,
#   1],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8,
#   4,
#   224,
#   1,
#   29],
#  [21,
#   218,
#   7,
#   219,
#   32,
#   132,
#   220,
#   2,
#   10,
#   55,
#   1,
#   131,
#   86,
#   38,
#   29,
#   7,
#   221,
#   118,
#   2,
#   8,
#   222,
#   29,
#   18,
#   87,
#   83,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   15,
#   1,
#   48,
#   35,
#   16,
#   17,
#   1,
#   84,
#   6,
#   87,
#   83,
#   4,
#   223,
#   49,
#   133,
#   85,
#   87,
#   49,
#   2,
#   9,
#   8,
#   4,
#   224,
#   1,
#   29,
#   119],
#  [133, 47],
#  [133, 47, 1],
#  [133, 47, 1, 12],
#  [133, 47, 1, 12, 7],
#  [133, 47, 1, 12, 7, 225],
#  [133, 47, 1, 12, 7, 225, 20],
#  [133, 47, 1, 12, 7, 225, 20, 2],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52, 226],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52, 226, 6],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52, 226, 6, 31],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52, 226, 6, 31, 66],
#  [133, 47, 1, 12, 7, 225, 20, 2, 8, 35, 60, 31, 53, 62, 52, 226, 6, 31, 66, 2],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1,
#   35],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1,
#   35,
#   16],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1,
#   35,
#   16,
#   86],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1,
#   35,
#   16,
#   86,
#   227],
#  [133,
#   47,
#   1,
#   12,
#   7,
#   225,
#   20,
#   2,
#   8,
#   35,
#   60,
#   31,
#   53,
#   62,
#   52,
#   226,
#   6,
#   31,
#   66,
#   2,
#   9,
#   19,
#   37,
#   4,
#   55,
#   1,
#   35,
#   16,
#   86,
#   227,
#   228],
#  [229, 230],
#  [229, 230, 81],
#  [229, 230, 81, 7],
#  [229, 230, 81, 7, 44],
#  [229, 230, 81, 7, 44, 134],
#  [231, 6],
#  [231, 6, 1],
#  [231, 6, 1, 232],
#  [231, 6, 1, 232, 12],
#  [231, 6, 1, 232, 12, 41],
#  [30, 10],
#  [30, 10, 3],
#  [30, 10, 3, 233],
#  [30, 10, 3, 233, 234],
#  [30, 10, 3, 233, 234, 17],
#  [30, 10, 3, 233, 234, 17, 71],
#  [30, 10, 3, 233, 234, 17, 71, 6],
#  [30, 10, 3, 233, 234, 17, 71, 6, 5],
#  [30, 10, 3, 233, 234, 17, 71, 6, 5, 63],
#  [30, 10, 3, 233, 234, 17, 71, 6, 5, 63, 85],
#  [30, 10, 3, 233, 234, 17, 71, 6, 5, 63, 85, 1],
#  [30, 10, 3, 233, 234, 17, 71, 6, 5, 63, 85, 1, 33],
#  [2, 9],
#  [2, 9, 8],
#  [2, 9, 8, 4],
#  [2, 9, 8, 4, 235],
#  [2, 9, 8, 4, 235, 5],
#  [2, 9, 8, 4, 235, 5, 74],
#  [2, 9, 8, 4, 235, 5, 74, 135],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236, 9],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236, 9, 59],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236, 9, 59, 2],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236, 9, 59, 2, 14],
#  [2, 9, 8, 4, 235, 5, 74, 135, 134, 17, 38, 77, 20, 34, 236, 9, 59, 2, 14, 5],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136,
#   18],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136,
#   18,
#   136],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136,
#   18,
#   136,
#   63],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136,
#   18,
#   136,
#   63,
#   137],
#  [2,
#   9,
#   8,
#   4,
#   235,
#   5,
#   74,
#   135,
#   134,
#   17,
#   38,
#   77,
#   20,
#   34,
#   236,
#   9,
#   59,
#   2,
#   14,
#   5,
#   136,
#   18,
#   136,
#   63,
#   137,
#   33],
#  [22, 3],
#  [22, 3, 36],
#  [22, 3, 36, 1],
#  [22, 3, 36, 1, 13],
#  [22, 3, 36, 1, 13, 76],
#  [22, 3, 36, 1, 13, 76, 10],
#  [22, 3, 36, 1, 13, 76, 10, 3],
#  [22, 3, 36, 1, 13, 76, 10, 3, 237],
#  [22, 3, 36, 1, 13, 76, 10, 3, 237, 238],
#  [22, 3, 36, 1, 13, 76, 10, 3, 237, 238, 48],
#  [22, 3, 36, 1, 13, 76, 10, 3, 237, 238, 48, 138],
#  [22, 3, 36, 1, 13, 76, 10, 3, 237, 238, 48, 138, 239],
#  [46, 139],
#  [46, 139, 240],
#  [46, 139, 240, 48],
#  [46, 139, 240, 48, 138],
#  [46, 139, 240, 48, 138, 63],
#  [46, 139, 240, 48, 138, 63, 17],
#  [46, 139, 240, 48, 138, 63, 17, 1],
#  [46, 139, 240, 48, 138, 63, 17, 1, 63],
#  [46, 139, 240, 48, 138, 63, 17, 1, 63, 137],
#  [46, 139, 240, 48, 138, 63, 17, 1, 63, 137, 74],
#  [46, 139, 240, 48, 138, 63, 17, 1, 63, 137, 74, 135],
#  [3, 23],
#  [3, 23, 123],
#  [3, 23, 123, 124],
#  [3, 23, 123, 124, 125],
#  [3, 23, 123, 124, 125, 20],
#  [3, 23, 123, 124, 125, 20, 3],
#  [3, 23, 123, 124, 125, 20, 3, 23],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39, 11],
#  [3, 23, 123, 124, 125, 20, 3, 23, 44, 37, 4, 26, 1, 25, 18, 1, 39, 11, 126],
#  [3,
#   23,
#   123,
#   124,
#   125,
#   20,
#   3,
#   23,
#   44,
#   37,
#   4,
#   26,
#   1,
#   25,
#   18,
#   1,
#   39,
#   11,
#   126,
#   3],
#  [3,
#   23,
#   123,
#   124,
#   125,
#   20,
#   3,
#   23,
#   44,
#   37,
#   4,
#   26,
#   1,
#   25,
#   18,
#   1,
#   39,
#   11,
#   126,
#   3,
#   28],
#  [2, 8],
#  [2, 8, 4],
#  [2, 8, 4, 59],
#  [2, 8, 4, 59, 60],
#  [2, 8, 4, 59, 60, 56],
#  [2, 8, 4, 59, 60, 56, 127],
#  [2, 8, 4, 59, 60, 56, 127, 5],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129, 241],
#  [2, 8, 4, 59, 60, 56, 127, 5, 57, 61, 128, 129, 241, 80],
#  [140, 20],
#  [140, 20, 40],
#  [140, 20, 40, 50],
#  [140, 20, 40, 50, 115],
#  [140, 20, 40, 50, 115, 130],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 242],
#  [11, 7, 1, 242, 4],
#  [11, 7, 1, 242, 4, 45],
#  [11, 7, 1, 242, 4, 45, 1],
#  [11, 7, 1, 242, 4, 45, 1, 140],
#  [243, 54],
#  [243, 54, 106],
#  [243, 54, 106, 244],
#  [2, 8],
#  [2, 8, 4],
#  [2, 8, 4, 24],
#  [2, 8, 4, 24, 1],
#  [2, 8, 4, 24, 1, 117],
#  [2, 8, 4, 24, 1, 117, 41],
#  [2, 8, 4, 24, 1, 117, 41, 6],
#  [2, 8, 4, 24, 1, 117, 41, 6, 31],
#  [2, 8, 4, 24, 1, 117, 41, 6, 31, 53],
#  [2, 8],
#  [2, 8, 4],
#  [2, 8, 4, 245],
#  [2, 8, 4, 245, 15],
#  [2, 8, 4, 245, 15, 1],
#  [2, 8, 4, 245, 15, 1, 12],
#  [2, 8, 4, 245, 15, 1, 12, 246],
#  [3, 23],
#  [3, 23, 247],
#  [3, 23, 247, 76],
#  [3, 23, 247, 76, 107],
#  [3, 23, 247, 76, 107, 10],
#  [3, 23, 247, 76, 107, 10, 3],
#  [3, 23, 247, 76, 107, 10, 3, 24],
#  [3, 23, 247, 76, 107, 10, 3, 24, 25],
#  [3, 23, 247, 76, 107, 10, 3, 24, 25, 6],
#  [3, 23, 247, 76, 107, 10, 3, 24, 25, 6, 1],
#  [3, 23, 247, 76, 107, 10, 3, 24, 25, 6, 1, 141],
#  [3, 23, 247, 76, 107, 10, 3, 24, 25, 6, 1, 141, 69],
#  [2, 9],
#  [2, 9, 45],
#  [2, 9, 45, 5],
#  [2, 9, 45, 5, 116],
#  [2, 9, 45, 5, 116, 4],
#  [2, 9, 45, 5, 116, 4, 24],
#  [2, 9, 45, 5, 116, 4, 24, 41],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47, 2],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47, 2, 24],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47, 2, 24, 14],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47, 2, 24, 14, 1],
#  [2, 9, 45, 5, 116, 4, 24, 41, 6, 141, 69, 17, 38, 77, 47, 2, 24, 14, 1, 248],
#  [2,
#   9,
#   45,
#   5,
#   116,
#   4,
#   24,
#   41,
#   6,
#   141,
#   69,
#   17,
#   38,
#   77,
#   47,
#   2,
#   24,
#   14,
#   1,
#   248,
#   43],
#  [3, 8],
#  [3, 8, 132],
#  [3, 8, 132, 88],
#  [3, 8, 132, 88, 40],
#  [3, 8, 132, 88, 40, 50],
#  [3, 8, 132, 88, 40, 50, 7],
#  [3, 8, 132, 88, 40, 50, 7, 5],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13, 11],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13, 11, 142],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13, 11, 142, 143],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13, 11, 142, 143, 40],
#  [3, 8, 132, 88, 40, 50, 7, 5, 73, 6, 21, 13, 11, 142, 143, 40, 50],
#  [21, 7],
#  [21, 7, 4],
#  [21, 7, 4, 249],
#  [21, 7, 4, 249, 88],
#  [21, 7, 4, 249, 88, 40],
#  [21, 7, 4, 249, 88, 40, 50],
#  [21, 7, 4, 249, 88, 40, 50, 250],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32, 27],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32, 27, 252],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32, 27, 252, 144],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32, 27, 252, 144, 2],
#  [21, 7, 4, 249, 88, 40, 50, 250, 44, 251, 40, 144, 32, 27, 252, 144, 2, 253],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7,
#   11],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7,
#   11,
#   142],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7,
#   11,
#   142,
#   143],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7,
#   11,
#   142,
#   143,
#   40],
#  [21,
#   7,
#   4,
#   249,
#   88,
#   40,
#   50,
#   250,
#   44,
#   251,
#   40,
#   144,
#   32,
#   27,
#   252,
#   144,
#   2,
#   253,
#   254,
#   62,
#   14,
#   88,
#   255,
#   103,
#   256,
#   257,
#   32,
#   22,
#   2,
#   54,
#   258,
#   4,
#   36,
#   21,
#   12,
#   139,
#   14,
#   259,
#   3,
#   23,
#   260,
#   2,
#   9,
#   19,
#   261,
#   72,
#   7,
#   11,
#   142,
#   143,
#   40,
#   50],
#  [262, 263],
#  [262, 263, 16],
#  [264, 265],
#  [264, 265, 16],
#  [16, 112],
#  [16, 112, 266],
#  [16, 112, 266, 267],
#  [268, 18],
#  [268, 18, 269],
#  [268, 18, 269, 270],
#  [268, 18, 269, 270, 271]]

# %%
max_len = max([len(x) for x in input_sequences])
print(max_len)
# Out:
# 57

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  89,   1],
#        [  0,   0,   0, ...,  89,   1,  13],
#        [  0,   0,   0, ...,   0,  11,   7],
#        ...,
#        [  0,   0,   0, ..., 268,  18, 269],
#        [  0,   0,   0, ...,  18, 269, 270],
#        [  0,   0,   0, ..., 269, 270, 271]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (836, 56)

# %%
y.shape
# Out:
# (836,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=272)

# %%
y.shape
# Out:
# (836, 272)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(272, 100, input_length=56))
model.add(LSTM(150))

model.add(Dense(272, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.0574 - loss: 5.5144
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.0695 - loss: 5.0337
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0803 - loss: 4.9468
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0836 - loss: 4.8296
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.0667 - loss: 4.9295
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0860 - loss: 4.7044
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.1061 - loss: 4.6690
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.1353 - loss: 4.4206
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.1534 - loss: 4.2413
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.1818 - loss: 4.0635
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2173 - loss: 3.8673
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2367 - loss: 3.6331
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.2937 - loss: 3.4313
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.3096 - loss: 3.2753
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.3763 - loss: 3.0373
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.3657 - loss: 2.8920
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.3842 - loss: 2.7910
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.4366 - loss: 2.5988
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.4456 - loss: 2.4937
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4938 - loss: 2.2667
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.5441 - loss: 2.1312
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5510 - loss: 2.0250
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6232 - loss: 1.8687
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.5954 - loss: 1.8588
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6544 - loss: 1.6768
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6803 - loss: 1.6172
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6893 - loss: 1.5266
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7078 - loss: 1.4379
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7512 - loss: 1.3365
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.7898 - loss: 1.2391
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7875 - loss: 1.1901
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.7815 - loss: 1.1544
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8272 - loss: 1.0197
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8385 - loss: 0.9645
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8568 - loss: 0.9040
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8680 - loss: 0.8666
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8755 - loss: 0.8286
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8895 - loss: 0.8015
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8876 - loss: 0.7477
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9084 - loss: 0.6734
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9180 - loss: 0.6406
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9081 - loss: 0.6281
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9065 - loss: 0.6116
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9293 - loss: 0.5500
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9217 - loss: 0.5212
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9201 - loss: 0.5146
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9393 - loss: 0.4702
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9311 - loss: 0.4437
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9370 - loss: 0.4484
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9366 - loss: 0.4248
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9471 - loss: 0.3936
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9411 - loss: 0.3925
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9361 - loss: 0.3757
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9638 - loss: 0.3296
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9547 - loss: 0.3285
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9603 - loss: 0.3239
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9391 - loss: 0.3324
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9403 - loss: 0.3195
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9456 - loss: 0.3041
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9557 - loss: 0.2734
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9336 - loss: 0.3064
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9581 - loss: 0.2552
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9481 - loss: 0.2790
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9551 - loss: 0.2548
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9393 - loss: 0.2655
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9443 - loss: 0.2499
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9439 - loss: 0.2516
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9589 - loss: 0.2208
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9455 - loss: 0.2328
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9471 - loss: 0.2258
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9456 - loss: 0.2119
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9576 - loss: 0.2020
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9456 - loss: 0.2046
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9437 - loss: 0.1990
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9462 - loss: 0.2067
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9419 - loss: 0.2134
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9415 - loss: 0.1920
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9400 - loss: 0.2014
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9390 - loss: 0.1930
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9472 - loss: 0.1884
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9490 - loss: 0.1881
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9407 - loss: 0.1775
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9390 - loss: 0.1807
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9463 - loss: 0.1797
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9367 - loss: 0.1981
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9489 - loss: 0.1537
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9411 - loss: 0.1779
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9418 - loss: 0.1771
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9555 - loss: 0.1492
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9446 - loss: 0.1541
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9478 - loss: 0.1641
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9523 - loss: 0.1460
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9533 - loss: 0.1543
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9359 - loss: 0.1758
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9406 - loss: 0.1662
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9434 - loss: 0.1567
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9472 - loss: 0.1418
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9439 - loss: 0.1367
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9337 - loss: 0.1509
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9472 - loss: 0.1387

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 56, 100)             │          27,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 150)                 │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 272)                 │          41,072 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 656,618 (2.50 MB)
#  Trainable params: 218,872 (854.97 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 437,746 (1.67 MB)

# %%
import time
import numpy as np
text = "what is the fee"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# what is the fee of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# what is the fee of monthly
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# what is the fee of monthly subscription
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee of monthly subscription suppose
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is the fee of monthly subscription suppose if
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is the fee of monthly subscription suppose if i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# what is the fee of monthly subscription suppose if i pay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# what is the fee of monthly subscription suppose if i pay on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# what is the fee of monthly subscription suppose if i pay on 15th
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee of monthly subscription suppose if i pay on 15th jan

# %%
text = "what is "

for i in range(5):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is  the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is  the language
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# what is  the language spoken
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# what is  the language spoken by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is  the language spoken by the

# %%
text = "who can"

for i in range(5):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# who can we
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# who can we pay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# who can we pay the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# who can we pay the entire
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# who can we pay the entire amount

# %%
text = "how are "

for i in range(5):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# how are  lifetime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# how are  lifetime validity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# how are  lifetime validity is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# how are  lifetime validity is a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# how are  lifetime validity is a monthly

# %%
text = "Hello how are"

for i in range(7):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Hello how are lifetime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Hello how are lifetime validity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Hello how are lifetime validity is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Hello how are lifetime validity is a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Hello how are lifetime validity is a monthly
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Hello how are lifetime validity is a monthly subscription
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Hello how are lifetime validity is a monthly subscription model

# %%
text = "why is the"

for i in range(7):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# why is the validity
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# why is the validity of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# why is the validity of monthly
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# why is the validity of monthly subscription
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# why is the validity of monthly subscription suppose
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# why is the validity of monthly subscription suppose if
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# why is the validity of monthly subscription suppose if i
