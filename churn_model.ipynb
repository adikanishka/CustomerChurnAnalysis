# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
df=pd.read_csv("telco_data.csv")
df.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0           True
# 1              0           56.95       1889.50      0          False
# 2              0           53.85        108.15      1          False
# 3              0           42.30       1840.75      0          False
# 4              0           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
x=df.drop('Churn',axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85           True        False
# 1                 0           56.95       1889.50          False         True
# 2                 0           53.85        108.15          False         True
# 3                 0           42.30       1840.75          False         True
# 4                 0           70.70        151.65           True        False
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50          False         True
# 7028              0          103.20       7362.90           True        False
# 7029              0           29.60        346.45           True        False
# 7030              1           74.40        306.60          False         True
# 7031              0          105.65       6844.50          False         True
#
# ...

# %%
y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# Decision Tree Classifier

# %%
model_dt=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_dt.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.8045486851457001

# %% [markdown]
# Accuracy is Low. Since it is imbalanced data we have to classification report

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      1040
#            1       0.69      0.46      0.55       367
#
#     accuracy                           0.80      1407
#    macro avg       0.76      0.69      0.71      1407
# weighted avg       0.79      0.80      0.79      1407

# %% [markdown]
# to upsample by generating synthetic data

# %%
sm = SMOTEENN()
X_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(X_resampled, y_resampled,test_size=0.2)

# %%
model_dt_smote=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_dt_smote.fit(xr_train,yr_train)
yr_predict = model_dt_smote.predict(xr_test)
model_score_r = model_dt_smote.score(xr_test, yr_test)
print(model_score_r)
print(metrics.classification_report(yr_test, yr_predict))
# Out:
# 0.9233390119250426
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       531
#            1       0.92      0.94      0.93       643
#
#     accuracy                           0.92      1174
#    macro avg       0.92      0.92      0.92      1174
# weighted avg       0.92      0.92      0.92      1174

# %%
print(metrics.confusion_matrix(yr_test, yr_predict))
# Out:
# [[479  52]
#  [ 38 605]]

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_rf.predict(x_test)

# %%
model_rf.score(x_test,y_test)
# Out:
# 0.8152096659559346

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      1040
#            1       0.73      0.46      0.56       367
#
#     accuracy                           0.82      1407
#    macro avg       0.78      0.70      0.72      1407
# weighted avg       0.81      0.82      0.80      1407

# %%
sm = SMOTEENN()
X_resampled1, y_resampled1 = sm.fit_resample(x,y)

# %%
xr_train1,xr_test1,yr_train1,yr_test1=train_test_split(X_resampled1, y_resampled1,test_size=0.2)

# %%
model_rf_smote=RandomForestClassifier(n_estimators=200, criterion='gini', random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf_smote.fit(xr_train1,yr_train1)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, n_estimators=200,
#                        random_state=100)

# %%
yr_predict1 = model_rf_smote.predict(xr_test1)

# %%
model_score_r1 = model_rf_smote.score(xr_test1, yr_test1)

# %%
print(model_score_r1)
# Out:
# 0.9376601195559351

# %%
print(metrics.classification_report(yr_test1, yr_predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       537
#            1       0.92      0.97      0.94       634
#
#     accuracy                           0.94      1171
#    macro avg       0.94      0.93      0.94      1171
# weighted avg       0.94      0.94      0.94      1171

# %%
print(metrics.confusion_matrix(yr_test1, yr_predict1))
# Out:
# [[484  53]
#  [ 20 614]]

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import accuracy_score
predictions = model_rf_smote.predict(x_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy * 100:.2f}%")
probabilities = model_rf_smote.predict_proba(x_test)[:, 1]
threshold = 0.4  # Change this threshold
predictions_adjusted = (probabilities >= threshold).astype(int)

print(f"Adjusted Accuracy: {accuracy_score(y_test, predictions_adjusted) * 100:.2f}%")
# Out:
# Accuracy: 75.84%
# Adjusted Accuracy: 72.42%

# %% [markdown]
# With RF Classifier, also we got good results, better than Decision Tree.

# %% [markdown]
# we are selecting RandomForest Classifier

# %% [markdown]
# Pickling the model

# %%
import pickle

# %%
filename="churn_model.pkl"

# %%
pickle.dump(model_rf_smote, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
model_score_r1 = load_model.score(xr_test1, yr_test1)
model_score_r1
# Out:
# 0.9376601195559351

# %%
feature_columns = df.columns.tolist()  
with open('feature_columns.pkl', 'wb') as file:
    pickle.dump(feature_columns, file)
